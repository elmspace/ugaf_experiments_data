# %%
import pandas as pd
import networkx as nx

# %%
with open("./raw_data/PROTEINS_full_A.txt") as edge_file:
    edge_list = edge_file.readlines()
edge_list = [(int(i.split(",")[0]), int(i.split(",")[1])) for i in edge_list]
edge_list
# Out:
# [(12, 1),
#  (23, 1),
#  (33, 1),
#  (24, 2),
#  (32, 2),
#  (42, 2),
#  (25, 3),
#  (30, 3),
#  (35, 3),
#  (5, 4),
#  (29, 4),
#  (30, 4),
#  (39, 4),
#  (40, 4),
#  (4, 5),
#  (15, 5),
#  (29, 5),
#  (30, 5),
#  (39, 5),
#  (40, 5),
#  (7, 6),
#  (8, 6),
#  (27, 6),
#  (6, 7),
#  (8, 7),
#  (9, 7),
#  (6, 8),
#  (7, 8),
#  (20, 8),
#  (26, 8),
#  (7, 9),
#  (10, 9),
#  (11, 9),
#  (26, 9),
#  (36, 9),
#  (9, 10),
#  (11, 10),
#  (20, 10),
#  (22, 10),
#  (26, 10),
#  (36, 10),
#  (9, 11),
#  (10, 11),
#  (21, 11),
#  (1, 12),
#  (23, 12),
#  (33, 12),
#  (32, 13),
#  (34, 13),
#  (42, 13),
#  (15, 14),
#  (16, 14),
#  (35, 14),
#  (40, 14),
#  (5, 15),
#  (14, 15),
#  (16, 15),
#  (40, 15),
#  (14, 16),
#  (15, 16),
#  (39, 16),
#  (18, 17),
#  (19, 17),
#  (20, 17),
#  (37, 17),
#  (17, 18),
#  (19, 18),
#  (20, 18),
#  (17, 19),
#  (18, 19),
#  (20, 19),
#  (36, 19),
#  (8, 20),
#  (10, 20),
#  (17, 20),
#  (18, 20),
#  (19, 20),
#  (21, 20),
#  (22, 20),
#  (36, 20),
# ...
